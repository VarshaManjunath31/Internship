# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("/unemployment analysis (1).csv")

# %%
data.drop(columns = ['Country Code'], inplace = True)
data.set_index('Country Name', inplace = True)

# %%
data_T = data.T
data_T
# Out:
# Country Name  Africa Eastern and Southern  Afghanistan  \
# 1991                                 7.80        10.65
# 1992                                 7.84        10.82
# 1993                                 7.85        10.72
# 1994                                 7.84        10.73
# 1995                                 7.83        11.18
# 1996                                 7.84        10.96
# 1997                                 7.86        10.78
# 1998                                 7.81        10.80
# 1999                                 7.79        10.81
# 2000                                 7.72        10.81
# 2001                                 7.73        10.81
# 2002                                 7.96        11.26
# 2003                                 7.79        11.14
# 2004                                 7.31        10.99
# 2005                                 7.12        11.22
# 2006                                 6.99        11.10
# ...

# %%
data_T.columns
# Out:
# Index(['Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'Venezuela, RB', 'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World',
#        'Samoa', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=235)

# %%
data_T[['Afghanistan', 'India', 'Pakistan', 'Sri Lanka', 'Bangladesh', 'Nepal', 'United Kingdom', 'United States']]
# Out:
# Country Name  Afghanistan  India  Pakistan  Sri Lanka  Bangladesh  Nepal  \
# 1991                10.65   5.60      0.62      14.66        2.20   1.77
# 1992                10.82   5.73      0.66      14.22        2.33   1.71
# 1993                10.72   5.69      0.56      13.82        2.36   1.72
# 1994                10.73   5.74      0.59      13.03        2.38   1.89
# 1995                11.18   5.76      0.60      12.27        2.48   1.74
# 1996                10.96   5.74      0.60      11.35        2.51   1.82
# 1997                10.78   5.61      0.54      10.60        2.69   1.83
# 1998                10.80   5.67      0.56       9.17        2.90   1.78
# 1999                10.81   5.74      0.57       8.88        3.06   1.85
# 2000                10.81   5.56      0.58       7.74        3.27   1.86
# 2001                10.81   5.58      0.56       7.90        3.62   1.75
# 2002                11.26   5.53      0.55       8.76        3.90   1.54
# ...

# %%
fig = px.line(data_T[['Afghanistan', 'India', 'Pakistan', 'Sri Lanka', 'Bangladesh', 'Nepal', 'United Kingdom', 'United States']])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(data_T['India'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
